# %% [markdown]
# # Day 3: Control Structures — Questions
#
# Fill the code cells below with your solutions and run each cell to test.

# %% [markdown]
# ## Conditional Logic

# %% [markdown]
# ### 1. Even or Odd
# Ask the user for a number and determine whether it is even or odd.

# %%
# Your solution here
#input
value = int(input("Enter a number"))
if value%2 == 0:
    print("Even number")
else:
    print("Odd number")


#even num %2==0
# Out:
# Even number

# %% [markdown]
# ### 2. Positive, Negative, or Zero
# Ask for a number and classify it as positive, negative, or zero.

# %%
# Your solution here

# %% [markdown]
# ### 3. Largest of Two Numbers
# Take two numbers and print the larger one.

# %%
# Your solution here

# %% [markdown]
# ### 4. Largest of Three Numbers
# Take three numbers and find the largest using conditional statements.

# %%
# Your solution here

# %% [markdown]
# ### 5. Grade Calculator
# Ask for a student's marks and print their grade based on predefined ranges.

# %%
# Your solution here

# %% [markdown]
# ### 6. Voting Eligibility
# Ask for age and determine whether the person is eligible to vote.

# %%
# Your solution here

# %% [markdown]
# ### 8. Login Check
# Ask for a username and password and check whether they match predefined credentials.

# %%
u_name = "saqlain"
password = "pass123"

Password = input("Enter your password: ")
User_Name = input("Enter your username: ")

if u_name == User_Name and password == Password:
    print("Login Success")
else:
    print("Invalid username or password")
# Out:
# Login Success

# %%
# # Your solution here
# name = "ahmed"
# pwd = "123"

# username = input("Please enter username")
# password = input("Please enter password")
# if(username == name and password==pwd):
#     print("Credentials match")
# else:
#     print("Credentials do NOT match")
# Out:
# Credentials do NOT match

# %% [markdown]
# ## For Loops

# %% [markdown]
# ### 1. Print 1–10
# Use a `for` loop to print numbers from 1 to 10.

# %%
# Your solution here
# for i in range(1, 11):

# %% [markdown]
# ### 2. Even Numbers
# Print all even numbers between 1 and 50.

# %%
# Your solution here
while ():
# find even number
# print even number

# %% [markdown]
# ### 3. Multiplication Table
# Ask for a number and print its multiplication table from 1 to 10.

# %%
# Your solution here

# %% [markdown]
# ### 4. Sum of Numbers
# Calculate the sum of numbers from 1 to 100 using a `for` loop.

# %%
# Your solution here

# %% [markdown]
# ### 5. Count Vowels
# Ask for a word or sentence and count the number of vowels.

# %%
# Your solution here

# %% [markdown]
# ### 6. Find Maximum
# Given a list of numbers, use a loop to find the largest number.

# %%
# Your solution here

# %% [markdown]
# ## While Loops

# %% [markdown]
# ### 1. Countdown
# Print numbers from 10 down to 1 using a `while` loop.

# %%
# Your solution here

# %% [markdown]
# ### 2. Sum Until Zero
# Keep asking the user for numbers and calculate their sum until they enter `0`.

# %%
# Your solution here

# %% [markdown]
# ### 3. Password Attempts
# Keep asking for a password until the correct password is entered.

# %%
# Your solution here

# %% [markdown]
# ### 4. Number Guessing Game
# Generate a random number between 1 and 100 and keep asking the user to guess until they get it right. Tell them whether their guess is too high or too low.

# %%
# Your solution here
number = 7 # random library
attempt = 0
for attempt in range(3):
     guess = int(input("Enter number you have 3 attempts: "))
     if guess == number:
        print("You guessed it right!")
        break
else:
    print("You ran out of attempts")

# max 3 tries
# code with bonus challenge Done
# Out:
# You ran out of attempts

# %% [markdown]
# ---
#
# **Instructions:** Fill each code cell with your solution. Use `Run` to execute and test. Good luck!
