# %% [markdown]
# # Day 5: File Handling — Questions
#
# Fill each code cell with your solution and run to test.

# %% [markdown]
# ## File Handling Tasks

# %% [markdown]
# ### Create and Write to a File
# Create a text file and write a few lines of information to it.

# %%
# Your solution here

# %% [markdown]
# ### Read a File
# Read and display the contents of an existing text file.

# %%
# Your solution here

# %% [markdown]
# ### Append Data
# Add new information to an existing file without deleting its previous contents.

# %%
# Your solution here

# %% [markdown]
# ### Student Records
# Store student names and marks in a file and display the saved records.

# %%
# Your solution here

# %% [markdown]
# ### Count File Content
# Read a text file and count the number of lines, words, and characters.

# %%
# Your solution here

# %% [markdown]
# ### Search in a File
# Ask the user for a word and check whether it exists in a text file.

# %%
# Your solution here

# %% [markdown]
# ### Update a File
# Read a file, modify specific information, and save the updated content.

# %%
# Your solution here

# %% [markdown]
# ### File-Based To-Do List
# Create a simple to-do list where tasks can be added and displayed using a file.

# %%
# Your solution here

# %% [markdown]
# ### File Management with os
# Create a folder, check whether a file exists, list files in a directory, and rename or delete a file.

# %%
# Your solution here

# %% [markdown]
# ---
#
# **Instructions:** Replace each placeholder with working code. Use file paths relative to the notebook folder for portability.
